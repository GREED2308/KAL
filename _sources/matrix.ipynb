# %% [markdown]
# ## Matrix
# ### Definisi matrix
#
# ## Operasi aritmatika matrix
# ## Penjumlahan
# ### Konsep Penjumlahan Matrix

# %% [markdown]
# ## Perkalian matrix
# ### Konsep pekalian matrix
